# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# #### Define image size

# %%
BATCH_SIZE = 32
IMAGE_SIZE = (128,128)

# %% [markdown]
# #### Stores dataset folder paths.

# %%
train_data_dir = "../dataset/cats_dogs/train"
test_data_dir = "../dataset/cats_dogs/test"

# %% [markdown]
# #### Load datasets from folders

# %%
train_data = tf.keras.utils.image_dataset_from_directory(train_data_dir,
                                                         batch_size=BATCH_SIZE,
                                                         image_size=IMAGE_SIZE,
                                                         subset = 'training',
                                                         validation_split=0.1,
                                                         seed=42)

validation_data = tf.keras.utils.image_dataset_from_directory(train_data_dir,
                                                         batch_size=BATCH_SIZE,
                                                         image_size=IMAGE_SIZE,
                                                         subset = 'validation',
                                                         validation_split=0.1,
                                                         seed=42)

test_data = tf.keras.utils.image_dataset_from_directory(test_data_dir,
                                                         batch_size=BATCH_SIZE,
                                                         image_size=IMAGE_SIZE)
# Out:
# Found 8000 files belonging to 2 classes.
# Using 7200 files for training.
# Found 8000 files belonging to 2 classes.
# Using 800 files for validation.
# Found 2000 files belonging to 2 classes.

# %% [markdown]
# #### Check class names

# %%
class_names = train_data.class_names
class_names
# Out:
# ['cats', 'dogs']

# %% [markdown]
# #### Checks dataset shape

# %%
for image_batch, label_batch in train_data.take(1):
  print(image_batch.shape)
  print(label_batch.shape)
# Out:
# (32, 128, 128, 3)
# (32,)

# %% [markdown]
# #### Plot sample data

# %%
plt.figure(figsize=(10,4))
for image,label in train_data.take(1):
  for i in range(10):
    ax = plt.subplot(2,5,i+1)
    plt.imshow(image[i].numpy().astype("uint8"))
    plt.title(class_names[label[i]])
    plt.axis("off")

# %% [markdown]
# #### Displays raw pixel values

# %%
for image, label in train_data.take(1):
  for i in range(1):
    print(image)
# Out:
# tf.Tensor(
# [[[[101.00769   104.00769   109.00769  ]
#    [111.074585  112.71521   114.30505  ]
#    [117.635284  115.31354   112.59396  ]
#    ...
#    [129.86246   132.91324   136.22964  ]
#    [126.8725    133.10297   135.69281  ]
#    [128.9002    138.99207   139.94614  ]]
#
#   [[ 85.20029    88.20029    93.20029  ]
#    [ 99.3725     99.79227   101.78906  ]
#    [114.00287   112.997925  110.048706 ]
#    ...
#    [116.720825  120.720825  123.720825 ]
#    [119.9389    126.16937   128.75922  ]
#    [138.79547   147.0824    148.93893  ]]
#
#   [[ 92.54297    94.90234    99.58203  ]
#    [ 91.57605    91.986206   93.986206 ]
#    [105.38388   104.38388   101.75107  ]
#    ...
#    [120.73743   125.52237   128.52237  ]
#    [130.21445   135.21445   138.21445  ]
#    [127.32648   134.36554   136.68585  ]]
#
#   ...
#
#   [[118.07504   122.07504   125.07504  ]
#    [121.617584  125.617584  128.61758  ]
#    [130.54602   134.54602   137.54602  ]
#    ...
#    [ 81.51825    87.02301    96.76108  ]
#    [ 45.951294   50.819916   54.147003 ]
#    [ 91.09787    94.27139    92.35733  ]]
#
#    ...
#    [ 82.37793    67.37793    38.37793  ]
#    [ 84.95996    69.95996    40.95996  ]
#    [ 82.70801    67.70801    38.708008 ]]
#
#   ...
#
#   [[ 24.580078   18.748047    8.259766 ]
#    [ 12.879883   10.211914    6.84375  ]
#    [  8.954102    7.330078    7.286133 ]
#    ...
#    [ 40.75       39.62207    33.998047 ]
#    [ 37.166016   37.04004    29.166016 ]
#    [ 33.75       33.75       25.75     ]]
#
#   [[ 57.476562   49.40332    18.9375   ]
#    [ 18.091797   13.642578    0.       ]
#    [ 15.981445   15.90625    12.707031 ]
#    ...
#    [ 33.45508    35.353516   28.904297 ]
#    [ 35.251953   36.375977   29.59961  ]
#    [ 35.44922    36.573242   28.398438 ]]
#
#   [[100.72168    90.796875   41.382812 ]
#    [ 44.54004    39.473633    8.825195 ]
#    [  8.816406    9.066406    1.8916016]
#    ...
#    [ 22.342773   27.867188   21.550781 ]
#    [ 26.884766   31.517578   24.517578 ]
#    [ 29.81836    34.55957    26.442383 ]]]
#
#
#  ...
#
#
#  [[[231.86328   221.86328   186.86328  ]
#    [234.2811    224.2811    189.2811   ]
#    [236.32578   223.32578   188.32578  ]
#    ...
#    [166.11252   156.1633    142.11252  ]
#    [168.2579    160.84775   146.07822  ]
#    [ 97.2767     88.41342    81.9603   ]]
#
#   [[232.07797   222.07797   187.07797  ]
#    [232.42969   222.42969   187.42969  ]
#    [235.42969   222.42969   187.42969  ]
#    ...
#    [167.32422   156.98514   144.10394  ]
#    [166.96552   158.96552   146.43335  ]
#    [ 92.78439    84.05783    77.19455  ]]
#
#   [[233.2211    223.2211    188.2211   ]
#    [230.01877   220.01877   185.01877  ]
#    [234.3164    221.3164    186.3164   ]
#    ...
#    [166.40234   155.57425   144.1601   ]
#    [167.5263    159.27316   148.77945  ]
#    [ 94.22113    85.49457    78.63129  ]]
#
#   ...
#
#   [[171.13672   171.13672   173.13672  ]
#    [170.58984   170.58984   172.58984  ]
#    [175.8945    175.8945    177.8945   ]
#    ...
#    [219.0781    225.89056   241.06247  ]
#    [217.91797   224.15234   243.53516  ]
#    [207.28986   213.35547   232.82266  ]]
#
#   [[172.13672   172.13672   174.13672  ]
#    [171.58984   171.58984   173.58984  ]
#    [176.45236   176.45236   178.45236  ]
#    ...
#    [217.107     223.107     238.47418  ]
#    [223.19922   228.19922   248.19922  ]
#    [211.58984   216.58984   236.58984  ]]
#
#   [[173.13672   173.13672   175.13672  ]
#    [172.58984   172.58984   174.58984  ]
#    [177.4672    177.4672    179.4672   ]
#    ...
#    [220.5711    226.5711    241.9383   ]
#    [222.29297   227.29297   247.29297  ]
#    [209.97656   214.97656   234.97656  ]]]
#
#
#  [[[227.77405   186.94592   161.03967  ]
#    [195.75745   153.04651   136.18872  ]
#    [218.09619   174.54932   166.06494  ]
#    ...
#    [230.23438   199.23438   132.23438  ]
#   [[184.76024   181.76024   176.76024  ]
#    [183.80522   180.80522   175.80522  ]
#    [180.61678   177.61678   172.61678  ]
#    ...
#    [111.64104   111.64104   113.64104  ]
#    [147.52788   146.52788   151.52788  ]
#    [179.07019   177.07019   180.96863  ]]]], shape=(32, 128, 128, 3), dtype=float32)

# %% [markdown]
# #### Normalizes images

# %%
train_data = train_data.map(lambda x,y: (x/255, y))
validation_data = validation_data.map(lambda x,y: (x/255, y))
test_data = test_data.map(lambda x,y: (x/255, y))

# %% [markdown]
# #### Creates augmented images

# %%
data_augmentation = tf.keras.Sequential(
    [
        tf.keras.layers.RandomFlip("horizontal", input_shape=(128,128,3)),
        tf.keras.layers.RandomRotation(0.2),
        tf.keras.layers.RandomZoom(0.2)
    ]
)
# Out:
# D:\Programming\VsCode\Cat-Dog-classifier\venv\Lib\site-packages\keras\src\layers\preprocessing\data_layer.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ### CNN Model

# %%
model = tf.keras.Sequential([

    tf.keras.layers.Input(shape=(128,128,3)),

    data_augmentation,

    tf.keras.layers.Rescaling(1./255),

    # BLOCK 1
    tf.keras.layers.Conv2D(32, (3,3), padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.MaxPooling2D(),

    # BLOCK 2
    tf.keras.layers.Conv2D(64, (3,3), padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.MaxPooling2D(),

    # BLOCK 3
    tf.keras.layers.Conv2D(128, (3,3), padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.MaxPooling2D(),

    # REGULARIZATION
    tf.keras.layers.Dropout(0.3),

    # BETTER THAN FLATTEN
    tf.keras.layers.GlobalAveragePooling2D(),

    # CLASSIFIER
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.3),

    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %% [markdown]
# #### Check model summary

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)              │ (None, 128, 128, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling (Rescaling)                │ (None, 128, 128, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 128, 128, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 128, 128, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 64, 64, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 64, 64, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 64, 64, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 32, 32, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 32, 32, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 32, 32, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 128)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 110,785 (432.75 KB)
#  Trainable params: 110,337 (431.00 KB)
#  Non-trainable params: 448 (1.75 KB)

# %% [markdown]
# #### Compile the model

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# #### Training the model

# %%
history = model.fit(train_data,
                    epochs=30,
                    validation_data=validation_data)
# Out:
# Epoch 1/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 199s 834ms/step - accuracy: 0.5874 - loss: 0.6749 - val_accuracy: 0.4950 - val_loss: 0.7031
# Epoch 2/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 177s 786ms/step - accuracy: 0.6144 - loss: 0.6504 - val_accuracy: 0.4950 - val_loss: 0.7222
# Epoch 3/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 177s 785ms/step - accuracy: 0.6263 - loss: 0.6426 - val_accuracy: 0.5050 - val_loss: 0.9143
# Epoch 4/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 205s 798ms/step - accuracy: 0.6404 - loss: 0.6330 - val_accuracy: 0.5050 - val_loss: 0.9272
# Epoch 5/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 258s 1s/step - accuracy: 0.6581 - loss: 0.6173 - val_accuracy: 0.4925 - val_loss: 0.7229
# Epoch 7/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.6539 - loss: 0.6130 - val_accuracy: 0.5213 - val_loss: 0.8548
# Epoch 8/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 270s 1s/step - accuracy: 0.6643 - loss: 0.6080 - val_accuracy: 0.4950 - val_loss: 2.0922
# Epoch 9/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 263s 1s/step - accuracy: 0.6689 - loss: 0.6005 - val_accuracy: 0.4950 - val_loss: 2.5568
# Epoch 10/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 267s 1s/step - accuracy: 0.6819 - loss: 0.5970 - val_accuracy: 0.4950 - val_loss: 3.3217
# Epoch 11/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 322s 1s/step - accuracy: 0.6819 - loss: 0.5944 - val_accuracy: 0.4950 - val_loss: 2.2193
# Epoch 12/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 268s 1s/step - accuracy: 0.6850 - loss: 0.5913 - val_accuracy: 0.5113 - val_loss: 0.7589
# Epoch 13/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 260s 1s/step - accuracy: 0.6849 - loss: 0.5841 - val_accuracy: 0.5337 - val_loss: 0.7627
# Epoch 14/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 266s 1s/step - accuracy: 0.6904 - loss: 0.5813 - val_accuracy: 0.4950 - val_loss: 1.9804
# Epoch 15/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 323s 1s/step - accuracy: 0.6947 - loss: 0.5786 - val_accuracy: 0.5050 - val_loss: 2.3352
# Epoch 16/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 322s 1s/step - accuracy: 0.6886 - loss: 0.5785 - val_accuracy: 0.4963 - val_loss: 1.0490
# Epoch 17/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.6989 - loss: 0.5715 - val_accuracy: 0.5238 - val_loss: 0.7045
# Epoch 18/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 256s 1s/step - accuracy: 0.7046 - loss: 0.5635 - val_accuracy: 0.5050 - val_loss: 9.3276
# Epoch 19/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 473s 2s/step - accuracy: 0.7058 - loss: 0.5647 - val_accuracy: 0.4925 - val_loss: 1.3346
# Epoch 20/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 300s 1s/step - accuracy: 0.6999 - loss: 0.5624 - val_accuracy: 0.4950 - val_loss: 4.8711
# Epoch 21/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 290s 1s/step - accuracy: 0.7064 - loss: 0.5594 - val_accuracy: 0.4950 - val_loss: 4.9057
# Epoch 22/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 258s 1s/step - accuracy: 0.7138 - loss: 0.5557 - val_accuracy: 0.5050 - val_loss: 8.3630
# Epoch 23/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 262s 1s/step - accuracy: 0.7160 - loss: 0.5532 - val_accuracy: 0.5050 - val_loss: 9.8985
# Epoch 24/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 234s 1s/step - accuracy: 0.7103 - loss: 0.5526 - val_accuracy: 0.4950 - val_loss: 5.2494
# Epoch 25/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 212s 813ms/step - accuracy: 0.7149 - loss: 0.5492 - val_accuracy: 0.4900 - val_loss: 2.1525
# Epoch 26/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 182s 807ms/step - accuracy: 0.7210 - loss: 0.5433 - val_accuracy: 0.4950 - val_loss: 1.0525
# Epoch 27/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 178s 789ms/step - accuracy: 0.7219 - loss: 0.5407 - val_accuracy: 0.5050 - val_loss: 4.9448
# Epoch 28/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 178s 789ms/step - accuracy: 0.7201 - loss: 0.5400 - val_accuracy: 0.4950 - val_loss: 3.7820
# Epoch 29/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 204s 797ms/step - accuracy: 0.7237 - loss: 0.5410 - val_accuracy: 0.4950 - val_loss: 7.0953
# Epoch 30/30
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 206s 813ms/step - accuracy: 0.7215 - loss: 0.5400 - val_accuracy: 0.4850 - val_loss: 0.9915

# %%
history.history

# %% [markdown]
# #### Plots accuracy graph

# %%
fig = plt.figure()
plt.plot(history.history['accuracy'], color='teal', label='accuracy')
plt.plot(history.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# #### Plots loss graph

# %%
fig = plt.figure()
plt.plot(history.history['loss'], color='teal', label='loss')
plt.plot(history.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# #### Creates evaluation metrics

# %%
precision = tf.keras.metrics.Precision()
recall = tf.keras.metrics.Recall()
accuracy = tf.keras.metrics.BinaryAccuracy()

# %% [markdown]
# #### Evaluates model on test dataset

# %%
for batch in test_data.as_numpy_iterator():
  X, y = batch
  yhat = model.predict(X)
  precision.update_state(y, yhat)
  recall.update_state(y, yhat)
  accuracy.update_state(y, yhat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step

# %% [markdown]
# #### Displays final evaluation scores

# %%
precision.result()
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.4839809238910675>

# %%
recall.result()
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.7099999785423279>

# %%
accuracy.result()
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.476500004529953>
